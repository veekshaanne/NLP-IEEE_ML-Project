# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt;

# %%
# Out:
# head: cannot open 'data/SaleData.csv' for reading: No such file or directory

# %%
stock=pd.read_csv("/content/onestock.csv")

# %%
stock.head()
# Out:
#                          Local time     Open     High      Low    Close  \
# 0  16.06.2025 19:00:00.000 GMT+0530  312.609  312.609  312.609  312.609
# 1  16.06.2025 19:00:01.000 GMT+0530  313.219  313.359  313.219  313.359
# 2  16.06.2025 19:00:03.000 GMT+0530  313.699  313.699  313.649  313.649
# 3  16.06.2025 19:00:09.000 GMT+0530  314.319  314.319  314.319  314.319
# 4  16.06.2025 19:00:14.000 GMT+0530  314.319  314.319  314.319  314.319
#
#    Volume
# 0  0.0132
# 1  0.0036
# 2  0.0141
# 3  0.0132
# 4  0.0132

# %%
stock.shape
# Out:
# (2631, 6)

# %%
stock.describe()
# Out:
#               Open         High          Low        Close       Volume
# count  2631.000000  2631.000000  2631.000000  2631.000000  2631.000000
# mean    314.894131   314.897502   314.886054   314.889673     0.016097
# std       1.207043     1.207789     1.205394     1.206250     0.009505
# min     312.609000   312.609000   312.609000   312.609000     0.000900
# 25%     313.819000   313.819000   313.819000   313.819000     0.013200
# 50%     314.819000   314.829000   314.819000   314.819000     0.013200
# 75%     316.084000   316.089000   316.069000   316.079000     0.014100
# max     316.959000   316.959000   316.959000   316.959000     0.079200

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2631 entries, 0 to 2630
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Local time  2631 non-null   object
#  1   Open        2631 non-null   float64
#  2   High        2631 non-null   float64
#  3   Low         2631 non-null   float64
#  4   Close       2631 non-null   float64
#  5   Volume      2631 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 123.5+ KB

# %%
stock['Close'].describe()
# Out:
# count    2631.000000
# mean      314.889673
# std         1.206250
# min       312.609000
# 25%       313.819000
# 50%       314.819000
# 75%       316.079000
# max       316.959000
# Name: Close, dtype: float64

# %%
stock['Close'].plot(kind='box', vert=False, figsize=(14,6))
plt.show()

# %%
stock['Close'].plot(kind='density', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
ax = stock['Close'].plot(kind='density', figsize=(14,6))
ax.axvline(stock['Close'].mean(), color='red')
ax.axvline(stock['Close'].median(), color='green')

# %%
ax = stock['Close'].plot(kind='hist', figsize=(14,6))
ax.set_xlabel('values')
# Out:
# Text(0.5, 0, 'values')

# %%
stock.head()
# Out:
#                          Local time     Open     High      Low    Close  \
# 0  16.06.2025 19:00:00.000 GMT+0530  312.609  312.609  312.609  312.609
# 1  16.06.2025 19:00:01.000 GMT+0530  313.219  313.359  313.219  313.359
# 2  16.06.2025 19:00:03.000 GMT+0530  313.699  313.699  313.649  313.649
# 3  16.06.2025 19:00:09.000 GMT+0530  314.319  314.319  314.319  314.319
# 4  16.06.2025 19:00:14.000 GMT+0530  314.319  314.319  314.319  314.319
#
#    Volume
# 0  0.0132
# 1  0.0036
# 2  0.0141
# 3  0.0132
# 4  0.0132

# %%
corr=stock.drop('Local time', axis=1).corr()
corr
# Out:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999894  0.999703  0.999644  0.020593
# High    0.999894  1.000000  0.999607  0.999717  0.024321
# Low     0.999703  0.999607  1.000000  0.999887  0.010113
# Close   0.999644  0.999717  0.999887  1.000000  0.014332
# Volume  0.020593  0.024321  0.010113  0.014332  1.000000

# %%
fig = plt.figure(figsize=(8,8))
plt.matshow(corr, cmap='RdBu')
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);
plt.colorbar()
plt.show()

# %%
stock.plot(kind='scatter', x='Open', y='Close', figsize=(6,6))
# Out:
# <Axes: xlabel='Open', ylabel='Close'>

# %%
stock.plot(kind='scatter', x='Close', y='Volume', figsize=(8, 8))
plt.show()

# %%
stock['Product'] = stock['Close'] * stock['Volume']
stock['Product'].head()
# Out:
# 0    4.126439
# 1    1.128092
# 2    4.422451
# 3    4.149011
# 4    4.149011
# Name: Product, dtype: float64

# %%
stock.loc[stock['Local time'] == '16.06.2025 19:00:09.000 GMT+0530']
# Out:
#                          Local time     Open     High      Low    Close  \
# 3  16.06.2025 19:00:09.000 GMT+0530  314.319  314.319  314.319  314.319
#
#    Volume   Product
# 3  0.0132  4.149011

# %%
df = pd.DataFrame({
    'Population': [2798,5678,4356,45678,321],
    'GDP': [1785387, 2833687,3874437,2167744,4602367],
    'Surface Area': [984670,40679,5432,214900,321900],
    'HDI': [0.45,0.56,0.76,0.31,0.45],
    'Continent': ['Europe','Asia','Africa','South America','North America']
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
df
# Out:
#    Population      GDP  Surface Area   HDI      Continent
# 0        2798  1785387        984670  0.45         Europe
# 1        5678  2833687         40679  0.56           Asia
# 2        4356  3874437          5432  0.76         Africa
# 3       45678  2167744        214900  0.31  South America
# 4         321  4602367        321900  0.45  North America

# %%
df.index = ['Spain','India','CapeTown','Brazil','Mexico']

# %%
df
# Out:
#           Population      GDP  Surface Area   HDI      Continent
# Spain           2798  1785387        984670  0.45         Europe
# India           5678  2833687         40679  0.56           Asia
# CapeTown        4356  3874437          5432  0.76         Africa
# Brazil         45678  2167744        214900  0.31  South America
# Mexico           321  4602367        321900  0.45  North America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.index
# Out:
# Index(['Spain', 'India', 'CapeTown', 'Brazil', 'Mexico'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Spain to Mexico
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    5 non-null      int64
#  1   GDP           5 non-null      int64
#  2   Surface Area  5 non-null      int64
#  3   HDI           5 non-null      float64
#  4   Continent     5 non-null      object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 412.0+ bytes

# %%
df.size
# Out:
# 25

# %%
df.shape
# Out:
# (5, 5)

# %%
df.describe()
# Out:
#          Population           GDP   Surface Area       HDI
# count      5.000000  5.000000e+00       5.000000  5.000000
# mean   11766.200000  3.052724e+06  313516.200000  0.506000
# std    19061.798425  1.174086e+06  396736.335068  0.167422
# min      321.000000  1.785387e+06    5432.000000  0.310000
# 25%     2798.000000  2.167744e+06   40679.000000  0.450000
# 50%     4356.000000  2.833687e+06  214900.000000  0.450000
# 75%     5678.000000  3.874437e+06  321900.000000  0.560000
# max    45678.000000  4.602367e+06  984670.000000  0.760000

# %%
df.dtypes
# Out:
# Population        int64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# int64      3
# float64    1
# object     1
# Name: count, dtype: int64

# %%
df.loc['CapeTown']
# Out:
# Population         4356
# GDP             3874437
# Surface Area       5432
# HDI                0.76
# Continent        Africa
# Name: CapeTown, dtype: object

# %%
df.iloc[-1]
# Out:
# Population                321
# GDP                   4602367
# Surface Area           321900
# HDI                      0.45
# Continent       North America
# Name: Mexico, dtype: object

# %%
df['Population']
# Out:
# Spain        2798
# India        5678
# CapeTown     4356
# Brazil      45678
# Mexico        321
# Name: Population, dtype: int64

# %%
df[1:3]
# Out:
#           Population      GDP  Surface Area   HDI Continent
# India           5678  2833687         40679  0.56      Asia
# CapeTown        4356  3874437          5432  0.76    Africa

# %%
df.iloc[[0, 1, -1]]
# Out:
#         Population      GDP  Surface Area   HDI      Continent
# Spain         2798  1785387        984670  0.45         Europe
# India         5678  2833687         40679  0.56           Asia
# Mexico         321  4602367        321900  0.45  North America

# %%
df.loc[df['Population'] > 5678]
# Out:
#         Population      GDP  Surface Area   HDI      Continent
# Brazil       45678  2167744        214900  0.31  South America

# %%
df1=df
df1.drop(['India', 'Brazil'], axis=0)
# Out:
#           Population      GDP  Surface Area   HDI      Continent
# Spain           2798  1785387        984670  0.45         Europe
# CapeTown        4356  3874437          5432  0.76         Africa
# Mexico           321  4602367        321900  0.45  North America

# %%
df1.drop('GDP',axis=1)
# Out:
#           Population  Surface Area   HDI      Continent
# Spain           2798        984670  0.45         Europe
# India           5678         40679  0.56           Asia
# CapeTown        4356          5432  0.76         Africa
# Brazil         45678        214900  0.31  South America
# Mexico           321        321900  0.45  North America

# %%
df
# Out:
#           Population      GDP  Surface Area   HDI      Continent
# Spain           2798  1785387        984670  0.45         Europe
# India           5678  2833687         40679  0.56           Asia
# CapeTown        4356  3874437          5432  0.76         Africa
# Brazil         45678  2167744        214900  0.31  South America
# Mexico           321  4602367        321900  0.45  North America

# %%
df[['Population', 'GDP']] / 100
# Out:
#           Population       GDP
# Spain          27.98  17853.87
# India          56.78  28336.87
# CapeTown       43.56  38744.37
# Brazil        456.78  21677.44
# Mexico          3.21  46023.67

# %%
df['GDP Per Capita'] = df['GDP'] / df['Population']

# %%
df
# Out:
#           Population      GDP  Surface Area   HDI      Continent  \
# Spain           2798  1785387        984670  0.45         Europe
# India           5678  2833687         40679  0.56           Asia
# CapeTown        4356  3874437          5432  0.76         Africa
# Brazil         45678  2167744        214900  0.31  South America
# Mexico           321  4602367        321900  0.45  North America
#
#           GDP Per Capita
# Spain         638.093996
# India         499.064283
# CapeTown      889.448347
# Brazil         47.457069
# Mexico      14337.591900

# %%
df['Population'].sum()
# Out:
# np.int64(58831)

# %%
popu=df['Population']

# %%
popu.mean()
# Out:
# np.float64(11766.2)

# %%
popu.describe()
# Out:
# count        5.000000
# mean     11766.200000
# std      19061.798425
# min        321.000000
# 25%       2798.000000
# 50%       4356.000000
# 75%       5678.000000
# max      45678.000000
# Name: Population, dtype: float64

# %%
popu.quantile([.2, .4, .6, .8, 1])
# Out:
# 0.2     2302.6
# 0.4     3732.8
# 0.6     4884.8
# 0.8    13678.0
# 1.0    45678.0
# Name: Population, dtype: float64

# %%
df3=pd.DataFrame({'Name':['A','B','C','D','E'],'Attendance':[50,75,87,67,56],'Age':[12,np.nan,14,12,15],'Marks':[np.nan,50,50,45,21],'Year':[2,3,4,np.nan,2]})

# %%
df3
# Out:
#   Name  Attendance   Age  Marks  Year
# 0    A          50  12.0    NaN   2.0
# 1    B          75   NaN   50.0   3.0
# 2    C          87  14.0   50.0   4.0
# 3    D          67  12.0   45.0   NaN
# 4    E          56  15.0   21.0   2.0

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isnull(None)
# Out:
# True

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %%
pd.notnull(None)
# Out:
# False

# %%
pd.notna(np.nan)
# Out:
# False

# %%
pd.isnull(pd.Series([1, np.nan, 7]))
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
pd.isnull(df3)
# Out:
#     Name  Attendance    Age  Marks   Year
# 0  False       False  False   True  False
# 1  False       False   True  False  False
# 2  False       False  False  False  False
# 3  False       False  False  False   True
# 4  False       False  False  False  False

# %%
pd.Series([1, 2, np.nan]).count()
# Out:
# np.int64(2)

# %%
pd.Series([1, 2, np.nan]).sum()
# Out:
# np.float64(3.0)

# %%
pd.Series([2, 2, np.nan]).mean()
# Out:
# np.float64(2.0)

# %%
df4=df3
df4.dropna()
# Out:
#   Name  Attendance   Age  Marks  Year
# 2    C          87  14.0   50.0   4.0
# 4    E          56  15.0   21.0   2.0

# %%
df3
# Out:
#   Name  Attendance   Age  Marks  Year
# 0    A          50  12.0    NaN   2.0
# 1    B          75   NaN   50.0   3.0
# 2    C          87  14.0   50.0   4.0
# 3    D          67  12.0   45.0   NaN
# 4    E          56  15.0   21.0   2.0

# %%
df3.dropna(how='all')
# Out:
#   Name  Attendance   Age  Marks  Year
# 0    A          50  12.0    NaN   2.0
# 1    B          75   NaN   50.0   3.0
# 2    C          87  14.0   50.0   4.0
# 3    D          67  12.0   45.0   NaN
# 4    E          56  15.0   21.0   2.0

# %%
df5=df3
df5.dropna(how='any')
# Out:
#   Name  Attendance   Age  Marks  Year
# 2    C          87  14.0   50.0   4.0
# 4    E          56  15.0   21.0   2.0

# %%
df6=df3
df6.fillna(0)
# Out:
#   Name  Attendance   Age  Marks  Year
# 0    A          50  12.0    0.0   2.0
# 1    B          75   0.0   50.0   3.0
# 2    C          87  14.0   50.0   4.0
# 3    D          67  12.0   45.0   0.0
# 4    E          56  15.0   21.0   2.0

# %%
df7=df3

# %%
df7.fillna(method='ffill')
# Out:
# /tmp/ipython-input-791972451.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df7.fillna(method='ffill')
#   Name  Attendance   Age  Marks  Year
# 0    A          50  12.0    NaN   2.0
# 1    B          75  12.0   50.0   3.0
# 2    C          87  14.0   50.0   4.0
# 3    D          67  12.0   45.0   4.0
# 4    E          56  15.0   21.0   2.0

# %%
df3.isnull().values
# Out:
# array([[False, False, False,  True, False],
#        [False, False,  True, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False,  True],
#        [False, False, False, False, False]])

# %%
df6.isnull().values
# Out:
# array([[False, False, False,  True, False],
#        [False, False,  True, False, False],
#        [False, False, False, False, False],
#        [False, False, False, False,  True],
#        [False, False, False, False, False]])

# %%
pr=pd.DataFrame({'Age':[23,45,345,34],'Gender':['m','f','f','?']})

# %%
pr['Gender'].unique()
# Out:
# array(['m', 'f', '?'], dtype=object)

# %%
pr['Gender'].value_counts()
# Out:
# Gender
# f    2
# m    1
# ?    1
# Name: count, dtype: int64

# %%
pr['Gender'].replace('?', 'f')
# Out:
# 0    m
# 1    f
# 2    f
# 3    f
# Name: Gender, dtype: object

# %%
pr.replace({'Age': {345:35}})
# Out:
#    Age Gender
# 0   23      m
# 1   45      f
# 2   35      f
# 3   34      ?

# %%
pr[pr['Age'] > 100]
# Out:
#    Age Gender
# 2  345      f

# %%
pr.loc[pr['Age'] > 100, 'Age'] = pr.loc[pr['Age'] > 100, 'Age'] / 10
# Out:
# /tmp/ipython-input-1007498035.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[34.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   pr.loc[pr['Age'] > 100, 'Age'] = pr.loc[pr['Age'] > 100, 'Age'] / 10

# %%
pr
# Out:
#     Age Gender
# 0  23.0      m
# 1  45.0      f
# 2  34.5      f
# 3  34.0      ?

# %%
players=pd.DataFrame({'players':['VK','MSD','SC','RS'],'team':['RCB','CSK','CSK','MI']})

# %%
players
# Out:
#   players team
# 0      VK  RCB
# 1     MSD  CSK
# 2      SC  CSK
# 3      RS   MI

# %%
players.duplicated(subset=['team'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
players.duplicated(subset=['team'], keep='last')
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
players.drop_duplicates(subset=['team'],keep='last')
# Out:
#   players team
# 0      VK  RCB
# 2      SC  CSK
# 3      RS   MI

# %%
x = np.arange(-10, 11)

# %% [markdown]
# ---
#
#
#
# ---

# %%
plt.figure(figsize=(12, 6))
plt.plot(x, x ** 2)
plt.plot(x, -1 * (x ** 2))
